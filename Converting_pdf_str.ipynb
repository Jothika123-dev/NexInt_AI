# %% [markdown]
# <a href="https://colab.research.google.com/github/Jothika123-dev/NexInt_AI/blob/main/Converting_pdf_str.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pypdf
# !python your_script.py
# Out:
# ...
# python3: can't open file '/content/your_script.py': [Errno 2] No such file or directory

# %%
import pypdf

def pdf_to_text(pdf_path):
    text = ""
    with open(pdf_path, "rb") as f:
        reader = pypdf.PdfReader(f)
        print(f"Total Pages: {len(reader.pages)}")
        for i, page in enumerate(reader.pages):
            extracted = page.extract_text() or ""
            text += extracted
            print(f"Page {i+1} extracted: {len(extracted)} characters")
    return text

# ── Run it ──
pdf_path = "test_1.pdf"   # 👈 Your file
result = pdf_to_text(pdf_path)

print("\n--- EXTRACTED TEXT ---\n")
print(result)

# Optional: Save to a .txt file
with open("test_1_output.txt", "w", encoding="utf-8") as f:
    f.write(result)
print("\n✅ Saved to test_1_output.txt")
# Out:
# Total Pages: 3
# Page 1 extracted: 2631 characters
# Page 2 extracted: 2393 characters
# Page 3 extracted: 1582 characters
#
# --- EXTRACTED TEXT ---
#
# Data science is an
# interdisciplinary
#  academic field that uses
# statistics
# ,
# scientific  computing
# ,
# scientific
# methods
# , processing,
# scientific visualization
#  ,
# algorithms
# , and systems to extract
# extrapolate
# knowledge
#  from potentially noisy,
# structured
# , or
# unstructured data
# .
# [2]
#
# Data science plays a critical role in modern decision -making by enabling organizations to extract
# actionable insights from large and complex datasets.
# [3]
#  Data science also integrates domain knowledge
# from the underlying application domain (e.g., natural sciences, information technology, and
# medicine).
# [4]
#  Data science is multifaceted and can be described as a science, a research paradigm, a
# research method, a discipline, a workflow, and a profession.
# [5]
#
# ...
